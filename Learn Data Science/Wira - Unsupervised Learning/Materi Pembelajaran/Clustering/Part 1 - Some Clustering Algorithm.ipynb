# %%
from luwiji.cluster import illustration

# %% [markdown]
# # Clustering
# url : https://scikit-learn.org/stable/modules/clustering.html
#
# # Kmeans
# url : https://stanford.edu/~cpiech/cs221/handouts/kmeans.html </br>
# Harus tau jumlah klasternya
#
# # DBSCAN
# url : https://www.naftaliharris.com/blog/visualizing-dbscan-clustering/ </br>
# Tidak harus tau jumlah klaster, karena sudah otomatis

# %% [markdown]
# # Agglomerative Hierarchical Clustering

# %%
illustration.ahc

# %%
illustration.dendrogram

# %% [markdown]
# ### Cluster Distance

# %%
illustration.cluster_distance
